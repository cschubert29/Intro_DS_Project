# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
juvcrime_finan = pd.read_csv(r'../Data/Florida data/Merged_Datasets/juvenile_crime_vs_finances.csv')
grades= pd.read_csv(r'../Data/Florida data/FLDOE/District Grades/Grades Concatenated.csv')

# %%
juvcrime_finan.set_index('Year', inplace= True)

# %%
juvcrime_finan.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize= 20);

# %%
juvcrime_finan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1138 entries, 2016 to 1998
# Data columns (total 14 columns):
# Unnamed: 0       1138 non-null int64
# COUNTY NAME      1138 non-null object
# TOTALREV         1138 non-null float64
# TFEDREV          1138 non-null float64
# TSTREV           1138 non-null float64
# TLOCREV          1138 non-null float64
# TOTALEXP         1138 non-null float64
# TCURINST         1138 non-null float64
# TCURSSVC         1138 non-null float64
# TCURONON         1138 non-null float64
# TCAPOUT          1138 non-null float64
# TOTAL ARRESTS    1138 non-null int64
# JUVENILE POP     1138 non-null int64
# CRIME RATE       1138 non-null float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 133.4+ KB

# %%
crimeRate=juvcrime_finan['CRIME RATE']

# %%
crimeRate.head()
# Out:
# Year
# 2016    1.531458
# 2016    1.119674
# 2016    3.116398
# 2016    1.112553
# 2016    2.098372
# Name: CRIME RATE, dtype: float64

# %%
juvcrime_finan.head()
# Out:
#       Unnamed: 0 COUNTY NAME   TOTALREV   TFEDREV    TSTREV   TLOCREV  \
# Year
# 2016           0     Alachua   9.702167  1.270125  4.333970  4.098072
# 2016           1       Baker   8.530388  0.965414  6.065374  1.499600
# 2016           2         Bay   9.979338  0.934416  3.981534  5.063389
# 2016           3    Bradford  10.011229  1.574860  5.697130  2.739239
# 2016           4     Brevard   9.968929  1.037302  4.560299  4.371328
#
#       TOTALEXP  TCURINST  TCURSSVC  TCURONON   TCAPOUT  TOTAL ARRESTS  \
# Year
# 2016  9.340386  4.968435  3.352738  0.626344  0.328715            730
# 2016  8.362055  4.367453  3.266693  0.565974  0.145542             77
# 2016  9.527591  5.411936  2.667003  0.541305  0.797883           1234
# 2016  9.352776  5.072052  3.243606  0.945415  0.083593             60
# 2016  9.390130  5.292529  2.829184  0.455725  0.526518           2250
#
#       JUVENILE POP  CRIME RATE
# Year
# 2016         47667    1.531458
# 2016          6877    1.119674
# 2016         39597    3.116398
# 2016          5393    1.112553
# 2016        107226    2.098372

# %%
crimeRate.plot(figsize=(20,10), linewidth=5, fontsize=20)
