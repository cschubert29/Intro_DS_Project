# %%
import pandas as pd

df=pd.read_csv(r'C:\Users\lisbe\Documents\GitHub\Intro_DS_Project\Code\States_avg_naep', sep='\t', header= None ,
              names =['STATE', 'AVG_SCORE'])
df.head()
# Out:
#         STATE   AVG_SCORE
# 0     Alabama  238.459702
# 1      Alaska  246.731767
# 2     Arizona  242.473198
# 3    Arkansas  242.667889
# 4  California  238.616212

# %%
df2=pd.read_csv(r'C:\Users\lisbe\Documents\GitHub\Intro_DS_Project\Data\US-Educational-Finances\States_2014_Finances')
df2.head()
# Out:
#    Unnamed: 0  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  \
# 0        1122       9.941165         1.072977       5.447440       3.420747
# 1        1123      20.404990         2.371130      13.975693       4.058167
# 2        1124       8.858333         1.168489       3.371290       4.318554
# 3        1125      10.821887         1.151823       8.349755       1.320309
# 4        1126      11.629364         1.191235       6.170682       4.267447
#
#    TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  \
# 0          10.252576                 5.167401                      3.230092
# 1          20.890738                10.314596                      7.529114
# 2           8.591103                 4.134349                      3.027854
# 3          10.924942                 5.438571                      3.654925
# 4          11.648270                 5.709433                      3.469183
#
# ...

# %%
df2=df2.drop(['Unnamed: 0'], axis=1)

# %%
df3=pd.merge(df,df2, on='STATE')
df3.head()
# Out:
#         STATE   AVG_SCORE  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     Alabama  238.459702       9.941165         1.072977       5.447440
# 1      Alaska  246.731767      20.404990         2.371130      13.975693
# 2     Arizona  242.473198       8.858333         1.168489       3.371290
# 3    Arkansas  242.667889      10.821887         1.151823       8.349755
# 4  California  238.616212      11.629364         1.191235       6.170682
#
#    LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0       3.420747          10.252576                 5.167401
# 1       4.058167          20.890738                10.314596
# 2       4.318554           8.591103                 4.134349
# 3       1.320309          10.924942                 5.438571
# 4       4.267447          11.648270                 5.709433
#
#    SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE
# 0                      3.230092           0.794024                    0.784960
# ...

# %%
juv_pop=pd.read_csv(r'C:\Users\lisbe\Documents\GitHub\Intro_DS_Project\Data\Florida data\Juvenile Crime by County\FL_Juvenile_Pop.csv')
juv_pop.head()
# Out:
#             counts     1998     1999     2000     2001     2002     2003  \
# 0     All Counties  3557562  3611711  3654880  3714439  3774624  3820876
# 1   Alachua County    44683    44252    43856    43498    43272    42889
# 2     Baker County     6129     6087     6156     6129     6278     6248
# 3       Bay County    36257    36089    35580    35816    36003    36358
# 4  Bradford County     5861     5788     5719     5700     5624     5646
#
#       2004     2005     2006    ...        2009     2010     2011     2012  \
# 0  3890734  3968178  4022912    ...     3997283  3997428  3998773  4008860
# 1    42897    43358    44181    ...       44391    44289    44665    44913
# 2     6398     6569     6793    ...        7114     7024     6991     6885
# 3    36740    37645    38213    ...       37072    37089    36732    37073
# 4     5683     5728     5828    ...        5726     5640     5563     5535
#
#       2013     2014     2015     2016     2017     Total
# ...

# %%
FL_juv_crime=pd.read_excel(r'C:\Users\lisbe\Documents\GitHub\Intro_DS_Project\Data\Florida data\Juvenile Crime by County\UCR_Arrest_Breakdown_County_1998-2017 (2).xlsx',sheet_name=1)
FL_juv_crime.head()
# Out:
#   COUNTY NAME County Summary Data Unnamed: 2   Unnamed: 3  \
# 0         NaN                 NaN      Total  Arrest Rate
# 1         NaN          Population    Arrests  Per 100,000
# 2     Alachua              216249      15305      7077.49
# 3       Baker               21879       1068      4881.39
# 4         Bay              150119      10956      7298.21
#
#   Total Arrests  -  All Offenses Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                          Adult        NaN   Juvenile        NaN       Race
# 1                           Male     Female       Male     Female      White
# 2                          10038       3130       1600        537       6674
# 3                            803        114        122         29        786
# 4                           7511       1890       1152        403       8275
#
#   Unnamed: 9     ...      Unnamed: 218 Unnamed: 219 Miscellaneous  \
# 0        NaN     ...               NaN          NaN         Adult
# ...

# %%
FL_juv=pd.read_excel(r'C:\Users\lisbe\Documents\GitHub\Intro_DS_Project\Data\Florida data\Juvenile Crime by County\UCR_Arrest_Breakdown_County_1998-2017 (2).xlsx',sheet_name=2)
FL_juv
