# %%
import pandas as pd

# %%
gradR1217= pd.read_csv(r"../data/Florida data/fldoe/Graduation Rates/High School Graduation Rates 2012-2017.csv")

# %%
gradR1217
# Out:
#     High School Graduation Rates Unnamed: 1                       Unnamed: 2  \
# 0          Applied filters: None        NaN                              NaN
# 1                            NaN        NaN                              NaN
# 2                            NaN        NaN  % Withdrawn To Contract/Private
# 3                       District       Year                              NaN
# 4                     01-ALACHUA    2012-13                             0.0%
# 5                     01-ALACHUA    2013-14                             0.0%
# 6                     01-ALACHUA    2014-15                             0.0%
# 7                     01-ALACHUA    2015-16                             0.0%
# 8                     01-ALACHUA    2016-17                             1.1%
# 9                       02-BAKER    2012-13                             0.0%
# 10                      02-BAKER    2013-14                             0.0%
# ...
