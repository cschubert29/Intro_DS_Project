# %%
import pandas as pd

# %%
#here I'm reading all the discipline csv files we'll be using and concatenating
dis1617df= pd.read_csv("/Users/paulososa/github/Intro_DS_Project/Data/Florida data/FLDOE/Discipline/1617DisciplineReport.csv",header=3)
dis1516df= pd.read_csv("/Users/paulososa/github/Intro_DS_Project/Data/Florida data/FLDOE/Discipline/1516DisciplineReport.csv",header=3)
dis1415df= pd.read_csv("/Users/paulososa/github/Intro_DS_Project/Data/Florida data/FLDOE/Discipline/1415DisciplineReport.csv",header=3)
dis1112df= pd.read_csv("/Users/paulososa/github/Intro_DS_Project/Data/Florida data/FLDOE/Discipline/1112DisciplineReport.csv",header=3)

# %%
dis1213df.head()
# Out:
#    District # District Name Discipline Code  \
# 0           0       FLORIDA               C
# 1           0       FLORIDA               E
# 2           0       FLORIDA               F
# 3           0       FLORIDA               H
# 4           0       FLORIDA               I
#
#                              Discipline Description   White  \
# 0                               Corporal Punishment     932
# 1  Expelled Without Continuing Educational Services      70
# 2     Expelled With Continuing Educational Services     143
# 3               Suspension Extended Pending Hearing     148
# 4                              Suspension In-School  59,921
#
#   Black or African American Hispanic/Latino  Asian  \
# 0                       320              95      1
# 1                        73              31      3
# 2                       113              54      1
# 3                       248             144      8
# 4                    69,863          47,917  1,319
#
# ...
